# %%
## Loading the Libaries.
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset
from wrf import getvar, to_np, get_cartopy, latlon_coords, ll_to_xy, vertcross, interplevel,ALL_TIMES
import cartopy as cp
from glob import glob
from PyWRFFun import MonthTimeSeries

## Load the EPA Data Input File
EPAVar = (np.loadtxt("/home/mpasillaspablo/CIMIS/RH_Files/6_june_RH_cleaned.csv", delimiter=',',usecols=[1], skiprows=1))

### Set the Variable you want to look at. ####
Var = "rh2"
VarLabel = "Two-Meter Relative Humidity [%]"
# === Location of the EPA site===
lat_point = 38.535694
lon_point = -121.77636

## Loading the data for the whole month #############
files0 = sorted(glob("/data/wto/WRFOUT/Sac_NDown_UCM1_PBL2_FDDA0_250518/wrfout_d01_2020-06-*"))
files1 = sorted(glob("/data/wto/WRFOUT/Sac_NDown_UCM1_PBL2_FDDA1_250710/wrfout_d01_2020-06-*"))

# === Use first file to find grid location ===
sample_ds = Dataset(files0[0])
xy_loc = ll_to_xy(sample_ds, lat_point, lon_point, as_int=True)
x_idx, y_idx = int(xy_loc[0]), int(xy_loc[1])

# === Extract and accumulate T2 at the target location ===
Var0_all = []
Var1_all = []
Time_all = []

for ifile in range(0,len(files0)):

    Var0 = getvar(Dataset(files0[ifile]), Var, timeidx=ALL_TIMES) 
    Var0_all.extend(to_np([Var0[y_idx, x_idx]]))
    Time_all.append(Var0.Time.values)
    
    Var1 = getvar(Dataset(files1[ifile]), Var, timeidx=ALL_TIMES) 
    Var1_all.extend(to_np([Var1[y_idx, x_idx]]))

results = MonthTimeSeries(Time_all,[EPAVar,Var0_all,Var1_all],"#6 Davis - 2m Relative Humidity [%]",["EPA Data","WRF FDDA0","WRF FDDA1"],True)
print(results)
# Out:
# [[-11.935525034795564, -8.805111768185926], [15.645023254926324, 13.489996807807179], [0.8535482907377696, 0.8980008291908794]]

# %%
## Loading the Libaries.
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset
from wrf import getvar, to_np, get_cartopy, latlon_coords, ll_to_xy, vertcross, interplevel,ALL_TIMES
import cartopy as cp
from glob import glob
from PyWRFFun import MonthTimeSeries

## Load the EPA Data Input File
EPAVar = (np.loadtxt("/home/mpasillaspablo/CIMIS/RH_Files/13_june_RH_cleaned.csv", delimiter=',',usecols=[1], skiprows=1))

### Set the Variable you want to look at. ####
Var = "rh2"
VarLabel = "Two-Meter Relative Humidity [%]"
# === Location of the EPA site===
lat_point = 38.535694
lon_point = -121.77636

## Loading the data for the whole month #############
files0 = sorted(glob("/data/wto/WRFOUT/Sac_NDown_UCM1_PBL2_FDDA0_250518/wrfout_d01_2020-06-*"))
files1 = sorted(glob("/data/wto/WRFOUT/Sac_NDown_UCM1_PBL2_FDDA1_250710/wrfout_d01_2020-06-*"))

# === Use first file to find grid location ===
sample_ds = Dataset(files0[0])
xy_loc = ll_to_xy(sample_ds, lat_point, lon_point, as_int=True)
x_idx, y_idx = int(xy_loc[0]), int(xy_loc[1])

# === Extract and accumulate T2 at the target location ===
Var0_all = []
Var1_all = []
Time_all = []

for ifile in range(0,len(files0)):

    Var0 = getvar(Dataset(files0[ifile]), Var, timeidx=ALL_TIMES) 
    Var0_all.extend(to_np([Var0[y_idx, x_idx]]))
    Time_all.append(Var0.Time.values)
    
    Var1 = getvar(Dataset(files1[ifile]), Var, timeidx=ALL_TIMES) 
    Var1_all.extend(to_np([Var1[y_idx, x_idx]]))

results = MonthTimeSeries(Time_all,[EPAVar,Var0_all,Var1_all],"#13 Camino - 2m Relative Humidity [%]",["EPA Data","WRF FDDA0","WRF FDDA1"],True)
print(results)
# Out:
# [[-7.510037569614506, -4.379624303004868], [17.60880192940489, 18.91860834619403], [0.7545669041996089, 0.7366153297622743]]

# %%
## Loading the Libaries.
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset
from wrf import getvar, to_np, get_cartopy, latlon_coords, ll_to_xy, vertcross, interplevel,ALL_TIMES
import cartopy as cp
from glob import glob
from PyWRFFun import MonthTimeSeries

## Load the EPA Data Input File
EPAVar = (np.loadtxt("/home/mpasillaspablo/CIMIS/RH_Files/47_june_RH_cleaned.csv", delimiter=',',usecols=[1], skiprows=1))

### Set the Variable you want to look at. ####
Var = "rh2"
VarLabel = "Two-Meter Relative Humidity [%]"
# === Location of the EPA site===
lat_point = 38.535694
lon_point = -121.77636

## Loading the data for the whole month #############
files0 = sorted(glob("/data/wto/WRFOUT/Sac_NDown_UCM1_PBL2_FDDA0_250518/wrfout_d01_2020-06-*"))
files1 = sorted(glob("/data/wto/WRFOUT/Sac_NDown_UCM1_PBL2_FDDA1_250710/wrfout_d01_2020-06-*"))

# === Use first file to find grid location ===
sample_ds = Dataset(files0[0])
xy_loc = ll_to_xy(sample_ds, lat_point, lon_point, as_int=True)
x_idx, y_idx = int(xy_loc[0]), int(xy_loc[1])

# === Extract and accumulate T2 at the target location ===
Var0_all = []
Var1_all = []
Time_all = []

for ifile in range(0,len(files0)):

    Var0 = getvar(Dataset(files0[ifile]), Var, timeidx=ALL_TIMES) 
    Var0_all.extend(to_np([Var0[y_idx, x_idx]]))
    Time_all.append(Var0.Time.values)
    
    Var1 = getvar(Dataset(files1[ifile]), Var, timeidx=ALL_TIMES) 
    Var1_all.extend(to_np([Var1[y_idx, x_idx]]))

results = MonthTimeSeries(Time_all,[EPAVar,Var0_all,Var1_all],"#47 Brentwood - 2m Relative Humidity [%]",["EPA Data","WRF FDDA0","WRF FDDA1"],True)
print(results)
# Out:
# [[-10.163937291062974, -7.033524024453336], [15.67260741108627, 13.900753242896618], [0.8638631818542414, 0.9005805849539629]]
